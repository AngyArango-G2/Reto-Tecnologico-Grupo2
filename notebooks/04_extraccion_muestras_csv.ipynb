# %%
from google.colab import files
import pandas as pd

# SUBIR PRIMER ARCHIVO
print("SUBE incidentes_viales_validado.csv")
files.upload()

# SUBIR SEGUNDO ARCHIVO
print("SUBE incidentes_limpia_final (1).csv")
files.upload()

# LEER ARCHIVOS
df1 = pd.read_csv('/content/incidentes_viales_validado.csv')
df2 = pd.read_csv('/content/incidentes_limpia_final (1).csv')

# AGREGAR LOCATION
df1['Location'] = df2['location']

# GUARDAR
df1.to_csv('/content/incidentes_final.csv', index=False)

# DESCARGAR
files.download('/content/incidentes_final.csv')
# Out:
# SUBE incidentes_viales_validado.csv
#      <input type="file" id="files-77a618d5-da4f-47c2-9476-7af70e583617" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77a618d5-da4f-47c2-9476-7af70e583617">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install supabase pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from supabase import create_client
import pandas as pd

# DATOS SUPABASE
url = "TU_URL_SUPABASE"
key = "TU_API_KEY"

supabase = create_client(url, key)

# LEER CSV
df = pd.read_csv('/content/incidentes_final.csv')

# CONVERTIR A DICCIONARIOS
data = df.to_dict(orient='records')

# SUBIR
supabase.table('incidentes_viales').insert(data).execute()

print("Datos subidos correctamente")
# Out:
# ---------------------------------------------------------------------------
# SupabaseException                         Traceback (most recent call last)
# /tmp/ipykernel_9184/3273074237.py in <cell line: 0>()
#       6 key = "TU_API_KEY"
#       7
# ----> 8 supabase = create_client(url, key)
#       9
#      10 # LEER CSV
#
# /usr/local/lib/python3.12/dist-packages/supabase/_sync/client.py in create_client(supabase_url, supabase_key, options)
#     378     Client
#     379     """
# --> 380     return Client.create(
#     381         supabase_url=supabase_url, supabase_key=supabase_key, options=options
#     382     )
#
# /usr/local/lib/python3.12/dist-packages/supabase/_sync/client.py in create(cls, supabase_url, supabase_key, options)
#     107     ) -> "Client":
#     108         auth_header = options.headers.get("Authorization") if options else None
# --> 109         client = cls(supabase_url, supabase_key, options)
#     110
#     111         if auth_header is None:
#
# ...

# %%
import pandas as pd
from google.colab import files

df1 = pd.read_csv('/content/incidentes_viales_validado final (1).csv')
df2 = pd.read_csv('/content/incidentes_limpia_final (1).csv')

# Agregar columna location
df1['location'] = df2['location']

# Guardar archivo final
df1.to_csv('/content/incidentes_final.csv', index=False)

# Descargar
files.download('/content/incidentes_final.csv')
# Out:
# /tmp/ipykernel_9184/3217215544.py:5: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/incidentes_limpia_final (1).csv')

# %%
import pandas as pd
from google.colab import files

# Leer archivos
df1 = pd.read_csv('/content/incidentes_viales_validado final (1).csv')
df2 = pd.read_csv('/content/incidentes_limpia_final (1).csv')

# Tomar SOLO las filas necesarias
df1['location'] = df2['location'].iloc[:len(df1)].values

# Guardar
df1.to_csv('/content/incidentes_final.csv', index=False)

# Descargar
files.download('/content/incidentes_final.csv')
# Out:
# /tmp/ipykernel_9184/823603370.py:6: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/incidentes_limpia_final (1).csv')

# %%
from supabase import create_client
import pandas as pd
import math

# SUPABASE
url = "https://dutltpmxhiqltrfidvkq.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

supabase = create_client(url, key)

# LEER CSV
df = pd.read_csv('/content/incidentes_final.csv')

# LIMPIAR NULOS
df = df.where(pd.notnull(df), None)

# CONTINUAR DESDE DONDE SE QUEDÓ
inicio_global = 106361

# BLOQUES
chunk_size = 5000

# RECORRER RESTANTE
for inicio in range(inicio_global, len(df), chunk_size):

    fin = inicio + chunk_size

    chunk = df.iloc[inicio:fin]

    data = chunk.to_dict(orient='records')

    supabase.table('incidentes_viales').insert(data).execute()

    print(f'Subidos registros {inicio} a {fin}')
# Out:
# Subidos registros 106361 a 111361
# Subidos registros 111361 a 116361
# Subidos registros 116361 a 121361
# Subidos registros 121361 a 126361
# Subidos registros 126361 a 131361
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9184/3633302285.py in <cell line: 0>()
#      30     data = chunk.to_dict(orient='records')
#      31
# ---> 32     supabase.table('incidentes_viales').insert(data).execute()
#      33
#      34     print(f'Subidos registros {inicio} a {fin}')
#
# /usr/local/lib/python3.12/dist-packages/postgrest/_sync/request_builder.py in execute(self)
#      88             :class:`APIError` If the API raised an error.
#      89         """
# ---> 90         r = send_with_retry(self.request)
#      91         try:
#      92             if r.is_success:
#
# /usr/local/lib/python3.12/dist-packages/postgrest/_sync/request_builder.py in send_with_retry(req)
# ...

# %%
import numpy as np

for inicio in range(inicio_global, total, chunk_size):

    fin = min(inicio + chunk_size, total)

    chunk = df.iloc[inicio:fin]

    # 🔥 limpieza real
    chunk = chunk.replace([np.nan, np.inf, -np.inf], None)

    data = chunk.to_dict(orient='records')

    try:
        supabase.table('incidentes_viales').insert(data).execute()
        print(f"✅ Subidos registros {inicio} a {fin}")

        with open("checkpoint.txt", "w") as f:
            f.write(str(fin))

    except Exception as e:
        print(f"❌ Error en {inicio}-{fin}: {e}")
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9184/3439698983.py in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 for inicio in range(inicio_global, total, chunk_size):
#       4
#       5     fin = min(inicio + chunk_size, total)
#
# NameError: name 'total' is not defined

# %%
import pandas as pd
import numpy as np
from supabase import create_client

# %%
url = "https://dutltpmxhiqltrfidvkq.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

supabase = create_client(url, key)

# %%
df = pd.read_csv('/content/incidentes_final.csv')
df = df.replace([np.nan, np.inf, -np.inf], None)

# %%
import pandas as pd

# Reemplaza con el nombre exacto si cambia
ruta_archivo = 'incidentes_limpia_final (1).csv'

# Leemos solo la primera columna para que cargue en un segundo y no consuma memoria
df = pd.read_csv(ruta_archivo, usecols=[0])

# Contamos las filas y sumamos 1 de la cabecera si quieres el total de líneas del archivo
print(f"El número exacto de filas (registros) es: {len(df)}")
# Out:
# El número exacto de filas (registros) es: 270765

# %%
from google.colab import drive
import pandas as pd

# 1. Esto creará un link y te pedirá autorización para conectar tu cuenta de Drive
drive.mount('/content/drive')

# 2. Una vez conectado, pones la ruta de donde guardaste el archivo en tu Drive
# (Por ejemplo, si lo subiste suelto en tu unidad, la ruta suele ser esta:)
ruta_drive = '/content/drive/MyDrive/incidentes_final (3).csv'

# 3. Probamos contar las filas rápido sin saturar la memoria
try:
    print("El número exacto de filas es:", sum(1 for row in open(ruta_drive, encoding='utf-8')) - 1)
except FileNotFoundError:
    print("El archivo no se encuentra en esa ruta de Drive. Revisa el nombre exacto.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# El archivo no se encuentra en esa ruta de Drive. Revisa el nombre exacto.

# %%
import os
import pandas as pd

def buscar_y_contar():
    nombre_buscado = "incidentes_final"
    encontrado = False

    # Recorremos tu Drive buscando el archivo
    for raiz, dirs, archivos in os.walk('/content/drive/MyDrive'):
        for archivo in archivos:
            if nombre_buscado in archivo and archivo.endswith('.csv'):
                ruta_real = os.path.join(raiz, archivo)
                print(f"¡Archivo encontrado en Drive!: {ruta_real}")

                # Contamos las filas de forma ultra rápida
                try:
                    with open(ruta_real, 'r', encoding='utf-8') as f:
                        filas = sum(1 for linea in f) - 1
                    print(f"El número exacto de filas es: {filas}")
                except Exception as e:
                    # Intento con otra codificación por si las moscas
                    with open(ruta_real, 'r', encoding='latin-1') as f:
                        filas = sum(1 for linea in f) - 1
                    print(f"El número exacto de filas es: {filas}")

                encontrado = True
                break
        if encontrado:
            break

    if not encontrado:
        print("No se encontró ningún archivo CSV que contenga 'incidentes_final' en tu Drive.")
        print("Asegúrate de que ya terminó de subirse por completo a tu cuenta de Google Drive.")

buscar_y_contar()
# Out:
# ¡Archivo encontrado en Drive!: /content/drive/MyDrive/incidentes_final (3).csv
# El número exacto de filas es: 250152

# %%
# !pip install supabase pandas

# %%
import pandas as pd
from supabase import create_client, Client

# 1. Configuración de tus credenciales de Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

# Configuración del archivo y la tabla
ruta_archivo = '/content/drive/MyDrive/incidentes_final (3).csv'
nombre_tabla = 'incidentes_final'  # Reemplaza con el nombre exacto de tu tabla si es otro

print("Conectando con el cliente de Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

try:
    # 2. ELIMINAR LOS DATOS VIEJOS
    # Nota: El cliente API requiere que apliquemos un filtro para ejecutar un delete masivo.
    # Usamos un filtro que abarque todos los años (por ejemplo, mayores a 0) para vaciarla por completo.
    print(f"Eliminando datos antiguos de la tabla '{nombre_tabla}'...")
    delete_result = supabase.table(nombre_tabla).delete().gt("año", 0).execute()
    print("¡Tabla vaciada correctamente!")

    # 3. SUBIR EL NUEVO ARCHIVO EN BLOQUES
    print("\nIniciando la carga del archivo por bloques...")

    # Subiremos de a 5.000 filas por lote para garantizar que la API de Supabase reciba los datos sin superar límites de timeout
    tamano_bloque = 5000

    for i, chunk in enumerate(pd.read_csv(ruta_archivo, chunksize=tamano_bloque)):
        # Reemplazamos valores nulos (NaN) por None para que se suban como NULL en SQL y evitemos errores
        chunk = chunk.where(pd.notnull(chunk), None)

        # Ajustamos el nombre de la columna con eñe para evitar dolores de cabeza en Postgres
        if 'diseño' in chunk.columns:
            chunk = chunk.rename(columns={'diseño': 'diseno'})

        # Convertimos las filas del bloque actual en un formato de lista de diccionarios (JSON)
        datos_json = chunk.to_dict(orient='records')

        # Enviamos el lote a Supabase
        supabase.table(nombre_tabla).insert(datos_json).execute()

        filas_procesadas = (i + 1) * tamano_bloque
        if filas_procesadas > 250152:
            filas_procesadas = 250152

        print(f"-> Bloque {i+1} cargado con éxito. (Total filas enviadas: {filas_procesadas} / 250.152)")

    print(f"\n¡Listo! El reemplazo se completó con éxito. Tus {filas_procesadas} filas ya están arriba.")

except Exception as e:
    print(f"\nOcurrió un error durante la migración: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2075/333002097.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from supabase import create_client, Client
#       3
#       4 # 1. Configuración de tus credenciales de Supabase
#       5 SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
#
# ModuleNotFoundError: No module named 'supabase'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 1. Forzamos la instalación de la librería primero
# !pip install supabase pandas

# 2. Esperamos un segundo a que cargue el sistema e importamos
import time
time.sleep(2)

import pandas as pd
from supabase import create_client, Client

# 3. Configuración de tus credenciales de Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

# Configuración del archivo y la tabla
ruta_archivo = '/content/drive/MyDrive/incidentes_final (3).csv'
nombre_tabla = 'incidentes_final'  # Reemplaza con el nombre exacto si es otro

print("Conectando con el cliente de Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

try:
    # 4. ELIMINAR LOS DATOS VIEJOS
    print(f"Eliminando datos antiguos de la tabla '{nombre_tabla}'...")
    # Filtramos por año mayor a 0 para asegurar que borre todo el histórico antiguo
    delete_result = supabase.table(nombre_tabla).delete().gt("año", 0).execute()
    print("¡Tabla vaciada correctamente!")

    # 5. SUBIR EL NUEVO ARCHIVO EN BLOQUES
    print("\nIniciando la carga del archivo por bloques...")

    # Subiremos de a 4.000 filas para ir sobre seguro con los límites de la API
    tamano_bloque = 4000

    for i, chunk in enumerate(pd.read_csv(ruta_archivo, chunksize=tamano_bloque)):
        # Reemplazamos valores nulos (NaN) por None para que SQL los reciba bien
        chunk = chunk.where(pd.notnull(chunk), None)

        # Ajustamos el nombre de la columna con eñe si existe
        if 'diseño' in chunk.columns:
            chunk = chunk.rename(columns={'diseño': 'diseno'})

        # Convertimos las filas a JSON (lista de diccionarios)
        datos_json = chunk.to_dict(orient='records')

        # Enviamos el lote actual a Supabase
        supabase.table(nombre_tabla).insert(datos_json).execute()

        filas_procesadas = (i + 1) * tamano_bloque
        if filas_procesadas > 250152:
            filas_procesadas = 250152
# Out:
#   File "/tmp/ipykernel_2075/2590518659.py", line 51
#     filas_procesadas = 250152
#                              ^
# SyntaxError: incomplete input

# %%
# 1. Instalamos e importamos todo en orden
# !pip install supabase pandas

import time
time.sleep(1)

import pandas as pd
from supabase import create_client, Client

# 2. Tus credenciales de Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

ruta_archivo = '/content/drive/MyDrive/incidentes_final (3).csv'
nombre_tabla = 'incidentes_final'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

try:
    # 3. Vaciar los datos anteriores
    print(f"Limpiando datos viejos de la tabla '{nombre_tabla}'...")
    supabase.table(nombre_tabla).delete().gt("año", 0).execute()
    print("¡Tabla vaciada correctamente!")

    # 4. Carga masiva por bloques
    print("\nIniciando la carga del archivo por bloques...")
    tamano_bloque = 4000

    for i, chunk in enumerate(pd.read_csv(ruta_archivo, chunksize=tamano_bloque)):
        # Limpieza de nulos para evitar conflictos con SQL
        chunk = chunk.where(pd.notnull(chunk), None)

        # Evitamos problemas de Postgres con la eñe reemplazando por 'diseno'
        if 'diseño' in chunk.columns:
            chunk = chunk.rename(columns={'diseño': 'diseno'})

        datos_json = chunk.to_dict(orient='records')

        # Subida del bloque
        supabase.table
# Out:
#   File "/tmp/ipykernel_2075/3611257311.py", line 41
#     supabase.table
#                   ^
# SyntaxError: incomplete input

# %%
# 1. Instalamos e importamos todo en orden
# !pip install supabase pandas

import time
time.sleep(1)

import pandas as pd
from supabase import create_client, Client

# 2. Tus credenciales de Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

ruta_archivo = '/content/drive/MyDrive/incidentes_final (3).csv'
nombre_tabla = 'incidentes_final'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

try:
    # 3. Vaciar los datos anteriores
    print(f"Limpiando datos viejos de la tabla '{nombre_tabla}'...")
    supabase.table(nombre_tabla).delete().gt("año", 0).execute()
    print("¡Tabla vaciada correctamente!")

    # 4. Carga masiva por bloques
    print("\nIniciando la carga del archivo por bloques...")
    tamano_bloque = 4000

    for i, chunk in enumerate(pd.read_csv(ruta_archivo, chunksize=tamano_bloque)):
        # Limpieza de nulos para evitar conflictos con SQL
        chunk = chunk.where(pd.notnull(chunk), None)

        # Evitamos problemas de Postgres con la eñe reemplazando por 'diseno'
        if 'diseño' in chunk.columns:
            chunk = chunk.rename(columns={'diseño': 'diseno'})

        datos_json = chunk.to_dict(orient='records')

        # Subida del bloque (Asegúrate de copiar esta línea completa)
        supabase.table(nombre_tabla).insert(datos_json).execute()

        # Cálculo de progreso
        filas_procesadas = (i + 1) * tamano_bloque
        if filas_procesadas > 250152:
            filas_procesadas = 250152

        print(f"-> Bloque {i+1} cargado con éxito. (Total filas enviadas: {filas_procesadas} / 250.152)")

    print(f"\n¡Listo! El proceso terminó con éxito. Tus {filas_procesadas} filas ya están en Supabase.")

except Exception as e:
    print(f"\nOcurrió un error durante la migración: {e}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.2 MB/s eta 0:00:00
# ...
# Conectando con Supabase...
# Limpiando datos viejos de la tabla 'incidentes_final'...
#
# Ocurrió un error durante la migración: {'message': "Could not find the table 'public.incidentes_final' in the schema cache", 'code': 'PGRST205', 'hint': "Perhaps you meant the table 'public.incidentes_viales'", 'details': None}

# %%
# Cambia esta línea que estaba así:
# nombre_tabla = 'incidentes_final'

# Ponla exactamente así:
nombre_tabla = 'incidentes_viales'

# %%
nombre_tabla = 'incidentes_viales'

# %%
# 1. Aseguramos librerías
# !pip install supabase pandas

import pandas as pd
from supabase import create_client, Client

# 2. Credenciales
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"

ruta_archivo = '/content/drive/MyDrive/incidentes_final (3).csv'
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

try:
    print("\nIniciando la carga del archivo por bloques...")

    # Bajamos el tamaño a 2.000 filas por lote para que la API no se sature y suba fluido
    tamano_bloque = 2000

    for i, chunk in enumerate(pd.read_csv(ruta_archivo, chunksize=tamano_bloque)):
        # Reemplazar valores nulos (NaN) para que SQL los acepte
        chunk = chunk.where(pd.notnull(chunk), None)

        # Corregir la eñe por si acaso
        if 'diseño' in chunk.columns:
            chunk = chunk.rename(columns={'diseño': 'diseno'})

        datos_json = chunk.to_dict(orient='records')

        # Subida directa del bloque actual
        supabase.table(nombre_tabla).insert(datos_json).execute()

        # Mostrar progreso real en pantalla
        filas_procesadas = (i + 1) * tamano_bloque
        if filas_procesadas > 275152:
            filas_procesadas = 275152

        print(f"-> Bloque {i+1} cargado con éxito. (Total filas enviadas: {filas_procesadas} / 275.152)")

    print(f"\n¡Espectacular! El proceso terminó con éxito. Tus {filas_procesadas} filas ya están en Supabase.")

except Exception as e:
    print(f"\nOcurrió un error durante la migración: {e}")
# Out:
# ...
# Conectando con Supabase...
#
# Iniciando la carga del archivo por bloques...
#
# Ocurrió un error durante la migración: [Errno 2] No such file or directory: '/content/drive/MyDrive/incidentes_final (3).csv'

# %%
# 1. Aseguramos librerías
# !pip install supabase pandas

import os
import pandas as pd
from supabase import create_client, Client

# 2. Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Rastreador automático del archivo en tu Drive
print("Buscando el archivo 'incidentes_final' en tu Drive...")
ruta_real = None
nombre_buscado = "incidentes_final"

for raiz, dirs, archivos in os.walk('/content/drive/MyDrive'):
    for archivo in archivos:
        if nombre_buscado in archivo and archivo.endswith('.csv'):
            ruta_real = os.path.join(raiz, archivo)
            print(f"¡Archivo localizado con éxito en!: {ruta_real}")
            break
    if ruta_real:
        break

if not ruta_real:
    print("\n[ALERTA] No se encontró ningún archivo CSV con el nombre 'incidentes_final' en tu Drive.")
    print("Por favor, verifica que ya terminó de subirse a tu cuenta de Google Drive.")
else:
    # 4. Iniciar la carga masiva en bloques
    try:
        print("\nIniciando la carga del archivo por bloques...")
        tamano_bloque = 2000

        for i, chunk in enumerate(pd.read_csv(ruta_real, chunksize=tamano_bloque)):
            # Cambiar nulos por None para evitar conflictos con SQL
            chunk = chunk.where(pd.notnull(chunk), None)

            # Corregir la columna de la eñe si viene con tilde
            if 'diseño' in chunk.columns:
                chunk = chunk.rename(columns={'diseño': 'diseno'})

            datos_json = chunk.to_dict(orient='records')

            # Subir el bloque actual
            supabase.table(nombre_tabla).insert(datos_json).execute()

            filas_procesadas = (i + 1) * tamano_bloque
            # Ajustamos la visualización al total real que tienes
            if filas_procesadas > 275152:
                filas_procesadas = 275152

            print(f"-> Lote {i+1} guardado. (Total filas en Supabase: {filas_procesadas} / 275.152)")

        print(f"\n¡Espectacular! Migración completada. Tus {filas_procesadas} filas están listas en la tabla '{nombre_tabla}'.")

    except Exception as e:
        print(f"\nOcurrió un error durante la carga: {e}")
# Out:
# ...
# Conectando con Supabase...
# Buscando el archivo 'incidentes_final' en tu Drive...
#
# [ALERTA] No se encontró ningún archivo CSV con el nombre 'incidentes_final' en tu Drive.
# Por favor, verifica que ya terminó de subirse a tu cuenta de Google Drive.

# %%
# 1. Aseguramos librerías
# !pip install supabase pandas

import os
import pandas as pd
from supabase import create_client, Client

# 2. Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

# Ruta local directa en Colab
ruta_local = 'incidentes_final (3).csv'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Validar si el archivo ya terminó de subirse a la barra lateral
if not os.path.exists(ruta_local):
    print(f"\n[ALERTA] Aún no se detecta el archivo '{ruta_local}' en la barra lateral de Colab.")
    print("Asegúrate de arrastrarlo a la carpeta de la izquierda y esperar que termine de cargar por completo.")
else:
    try:
        print("\n¡Archivo detectado! Iniciando la carga por bloques a Supabase...")

        # Procesamos de a 2.000 filas para que la subida sea fluida y sin bloqueos
        tamano_bloque = 2000

        for i, chunk in enumerate(pd.read_csv(ruta_local, chunksize=tamano_bloque)):
            # Reemplazar valores nulos (NaN) para que SQL no genere errores
            chunk = chunk.where(pd.notnull(chunk), None)

            # Ajustar la eñe si viene con tilde
            if 'diseño' in chunk.columns:
                chunk = chunk.rename(columns={'diseño': 'diseno'})

            datos_json = chunk.to_dict(orient='records')

            # Subir lote actual a la tabla
            supabase.table(nombre_tabla).insert(datos_json).execute()

            filas_procesadas = (i + 1) * tamano_bloque
            if filas_procesadas > 275152:
                filas_procesadas = 275152

            print(f"-> Lote {i+1} guardado con éxito. (Progreso: {filas_procesadas} / 275.152 filas)")

        print(f"\n¡Espectacular! Migración completada con éxito. Las {filas_procesadas} filas están listas en '{nombre_tabla}'.")

    except Exception as e:
        print(f"\nOcurrió un error durante la carga: {e}")
# Out:
# ...
# Conectando con Supabase...
#
# [ALERTA] Aún no se detecta el archivo 'incidentes_final (3).csv' en la barra lateral de Colab.
# Asegúrate de arrastrarlo a la carpeta de la izquierda y esperar que termine de cargar por completo.

# %%
# 1. Aseguramos que la librería de Supabase esté instalada
# !pip install supabase pandas

import io
import pandas as pd
from google.colab import files
from supabase import create_client, Client

# 2. Credenciales de tu proyecto en Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Botón interactivo para subir tu archivo CSV
print("\nPor favor, dale clic al botón de abajo y selecciona tu archivo CSV:")
uploaded = files.upload()

# Verificamos si se seleccionó un archivo
if not uploaded:
    print("\n[ALERTA] No seleccionaste ningún archivo. Vuelve a correr la celda.")
else:
    # Obtenemos el nombre del archivo cargado
    nombre_archivo = list(uploaded.keys())[0]
    print(f"\n¡Archivo '{nombre_archivo}' recibido con éxito en Colab!")

    try:
        print("Leyendo los datos e iniciando la carga por bloques a Supabase...")
        # Leemos el archivo directamente desde la memoria de Colab
        contenido = uploaded[nombre_archivo]

        # Procesamos en bloques de 2000 filas para que suba rápido y sin errores de red
        tamano_bloque = 2000

        # Usamos io.BytesIO para leer el archivo en memoria sin guardarlo en el disco
        for i, chunk in enumerate(pd.read_csv(io.BytesIO(contenido), chunksize=tamano_bloque)):
            # Cambiar valores nulos por None para que la base de datos los acepte bien
            chunk = chunk.where(pd.notnull(chunk), None)

            # Corregimos el nombre de la columna con eñe si hace falta
            if 'diseño' in chunk.columns:
                chunk = chunk.rename(columns={'diseño': 'diseno'})

            datos_json = chunk.to_dict(orient='records')

            # Subida directa del bloque actual a Supabase
            supabase.table(nombre_tabla).insert(datos_json).execute()

            filas_procesadas = (i + 1) * tamano_bloque
            print(f"-> Bloque {i+1} guardado con éxito. (Total filas enviadas: {filas_procesadas})")

        print(f"\n¡Espectacular! Todo el archivo se subió correctamente a la tabla '{nombre_tabla}'.")

    except Exception as e:
        print(f"\nOcurrió un error durante la carga de datos: {e}")
# Out:
# ...
# Conectando con Supabase...
#
# Por favor, dale clic al botón de abajo y selecciona tu archivo CSV:
#      <input type="file" id="files-95cc44d2-516f-44da-b07e-ff04a5e95462" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95cc44d2-516f-44da-b07e-ff04a5e95462">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# 1. Instalamos la librería oficial de Supabase
# !pip install supabase pandas

import os
import pandas as pd
from supabase import create_client, Client

# 2. Configuración de credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'
ruta_archivo = 'incidentes_final.csv'  # Archivo subido a la izquierda de Colab

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Validar si el archivo ya terminó de cargar en Colab
if not os.path.exists(ruta_archivo):
    print(f"\n[ALERTA] No se encuentra el archivo '{ruta_archivo}' en la barra lateral.")
    print("Asegúrate de arrastrarlo a la carpeta de la izquierda y que se llame exactamente así.")
else:
    try:
        print("\n¡Archivo detectado con éxito!")
        print("Iniciando la carga masiva por bloques... (Por favor, no cierres la pestaña)\n")

        # Procesamos de a 2000 filas para que la API de Supabase vuele sin saturarse
        tamano_bloque = 2000
        total_filas_estimado = 216950

        for i, chunk in enumerate(pd.read_csv(ruta_archivo, chunksize=tamano_bloque)):
            # Convertimos valores nulos (NaN) a None para que Postgres los entienda como NULL
            chunk = chunk.where(pd.notnull(chunk), None)

            # Reemplazamos la eñe por si la columna en Supabase se creó sin tilde/eñe
            if 'diseño' in chunk.columns:
                chunk = chunk.rename(columns={'diseño': 'diseno'})

            # Convertimos el bloque actual a formato JSON
            datos_json = chunk.to_dict(orient='records')

            # Insertar el lote en Supabase
            supabase.table(nombre_tabla).insert(datos_json).execute()

            # Control de progreso en pantalla
            filas_procesadas = (i + 1) * tamano_bloque
            if filas_procesadas > total_filas_estimado:
                filas_procesadas = total_filas_estimado

            porcentaje = (filas_procesadas / total_filas_estimado) * 100
            print(f"-> Lote {i+1} enviado exitosamente. Progreso: {filas_procesadas:,} / {total_filas_estimado:,} filas ({porcentaje:.1f}%)")

        print(f"\n¡LOGRADO! Las {filas_procesadas:,} filas quedaron perfectamente cargadas en la tabla '{nombre_tabla}'.")

    except Exception as e:
        print(f"\nOcurrió un error durante la carga: {e}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.0 MB/s eta 0:00:00
# ...
# Conectando con Supabase...
#
# [ALERTA] No se encuentra el archivo 'incidentes_final.csv' en la barra lateral.
# Asegúrate de arrastrarlo a la carpeta de la izquierda y que se llame exactamente así.

# %%
# 1. Aseguramos que la librería de Supabase esté instalada
# !pip install supabase pandas

import io
import pandas as pd
from google.colab import files
from supabase import create_client, Client

# 2. Credenciales directas de tu proyecto en Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Interfaz automática para que subas el archivo desde tu computador
print("\n========================================================")
print("¡DALE CLIC AL BOTÓN DE ABAJO PARA SELECCIONAR TU ARCHIVO!")
print("========================================================\n")

# Esto abre el selector nativo de archivos en tu pantalla
archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] Cancelaste la selección o no elegiste ningún archivo. Vuelve a darle Play.")
else:
    # Capturamos el archivo que hayas elegido sin importar cómo se llame
    nombre_real_archivo = list(archivo_subido.keys())[0]
    print(f"\n[ÉXITO] Archivo '{nombre_real_archivo}' recibido correctamente en Colab.")

    try:
        print("Procesando datos en memoria e iniciando la carga por bloques a Supabase...\n")
        contenido_binario = archivo_subido[nombre_real_archivo]

        # Leemos en bloques de 2000 filas para que la subida sea fluida y no se cuelgue
        tamano_lote = 2000
        total_filas_estimado = 216950

        for i, chunk in enumerate(pd.read_csv(io.BytesIO(contenido_binario), chunksize=tamano_lote)):
            # Limpieza de valores nulos para que Postgres (SQL) los acepte como NULL
            chunk = chunk.where(pd.notnull(chunk), None)

            # Ajustamos la columna con eñe por si acaso
            if 'diseño' in chunk.columns:
                chunk = chunk.rename(columns={'diseño': 'diseno'})

            datos_en_json = chunk.to_dict(orient='records')

            # Subida en tiempo real del lote actual
            supabase.table(nombre_tabla).insert(datos_en_json).execute()

            filas_enviadas = (i + 1) * tamano_lote
            if filas_enviadas > total_filas_estimado:
                filas_enviadas = total_filas_estimado

            porcentaje = (filas_enviadas / total_filas_estimado) * 100
            print(f"-> Lote {i+1} guardado. Progreso: {filas_enviadas:,} / {total_filas_estimado:,} filas ({porcentaje:.1f}%)")

        print(f"\n¡LOGRADO POR FIN! Las {filas_enviadas:,} filas quedaron arriba en tu tabla '{nombre_tabla}'.")

    except Exception as e:
        print(f"\nOcurrió un error inesperado al procesar el archivo: {e}")
# Out:
# ...
# Conectando con Supabase...
#
# ...
# ¡DALE CLIC AL BOTÓN DE ABAJO PARA SELECCIONAR TU ARCHIVO!
# ...
#      <input type="file" id="files-3abd94a0-f93f-4979-8c62-22cb8e375f48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3abd94a0-f93f-4979-8c62-22cb8e375f48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# 1. Aseguramos que la librería de Supabase esté instalada
# !pip install supabase pandas

import io
import pandas as pd
from google.colab import files
from supabase import create_client, Client

# 2. Credenciales directas de tu proyecto en Supabase
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# 3. Interfaz automática para que subas el archivo desde tu computador
print("\n========================================================")
print("¡DALE CLIC AL BOTÓN DE ABAJO PARA SELECCIONAR TU ARCHIVO!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] Cancelaste la selección o no elegiste ningún archivo. Vuelve a darle Play.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    print(f"\n[ÉXITO] Archivo '{nombre_real_archivo}' recibido correctamente.")

    try:
        print("Procesando datos en memoria e iniciando la carga por bloques a Supabase...\n")
        contenido_binario = archivo_subido[nombre_real_archivo]

        # Procesamos en bloques de 2000 filas para mantener la estabilidad
        tamano_lote = 2000
        total_filas_estimado = 216950

        for i, chunk in enumerate(pd.read_csv(io.BytesIO(contenido_binario), chunksize=tamano_lote)):
            # Limpieza de valores nulos (NaN -> None) para evitar conflictos con SQL
            chunk = chunk.where(pd.notnull(chunk), None)

            # ELIMINADO EL RENOMBRADO FORZADO: Dejamos las columnas tal cual vienen en tu CSV
            datos_en_json = chunk.to_dict(orient='records')

            # Subida en tiempo real del lote actual
            supabase.table(nombre_tabla).insert(datos_en_json).execute()

            filas_enviadas = (i + 1) * tamano_lote
            if filas_enviadas > total_filas_estimado:
                filas_enviadas = total_filas_estimado

            porcentaje = (filas_enviadas / total_filas_estimado) * 100
            print(f"-> Lote {i+1} guardado. Progreso: {filas_enviadas:,} / {total_filas_estimado:,} filas ({porcentaje:.1f}%)")

        print(f"\n¡LOGRADO POR FIN! Las {filas_enviadas:,} filas quedaron arriba en tu tabla '{nombre_tabla}'.")

    except Exception as e:
        print(f"\nOcurrió un error inesperado al procesar el archivo: {e}")
# Out:
# ...
# Conectando con Supabase...
#
# ...
# ¡DALE CLIC AL BOTÓN DE ABAJO PARA SELECCIONAR TU ARCHIVO!
# ...
#      <input type="file" id="files-af851d9e-394f-41c4-ab03-79646935219a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af851d9e-394f-41c4-ab03-79646935219a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'paradas'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE PARADAS ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        try:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8')
        except:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='latin-1')

        print(f"✔ Archivo cargado. Filas totales detectadas en CSV: {len(df):,}")

        # 1. Mapeamos las columnas con los nombres correctos de tu base de datos
        df_mapeado = pd.DataFrame()

        df_mapeado['id_paradero'] = pd.to_numeric(df['id_paradero'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['id_parada'] = pd.to_numeric(df['id_parada'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['id_ruta'] = pd.to_numeric(df['id_ruta'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['nro_parada'] = pd.to_numeric(df['nro_parada'], errors='coerce').fillna(0).astype(np.int64)

        df_mapeado['nombre_ruta'] = df['nombre_ruta']
        df_mapeado['codigo_ruta'] = df['codigo_ruta']
        df_mapeado['tipo_ruta'] = df['tipo_ruta']
        df_mapeado['empresa'] = df['empresa']

        df_mapeado['longitud'] = pd.to_numeric(df['longitud'], errors='coerce')
        df_mapeado['latitud'] = pd.to_numeric(df['latitud'], errors='coerce')

        df_mapeado['recorrido'] = df['recorrido']
        df_mapeado['sistema_ruta'] = df['sistema_ruta']
        df_mapeado['tipo_parada'] = df['tipo_parada']

        # SOLUCIÓN AL ERROR 21000: Eliminamos paraderos duplicados dentro del mismo set de datos
        antes = len(df_mapeado)
        df_mapeado = df_mapeado.drop_duplicates(subset=['id_paradero'], keep='first')
        despues = len(df_mapeado)

        print(f"✔ Limpieza de conflicto: Se redujeron {antes - despues} filas repetidas en id_paradero.")
        print(f"✔ Filas únicas listas para subir de forma segura: {despues:,}")

        # Ajustamos los nulos para evitar conflictos con pandas
        df_mapeado = df_mapeado.replace({np.nan: None})

        # Subida masiva en bloques con UPSERT definitivo
        tamano_lote = 300
        datos_en_json = df_mapeado.to_dict(orient='records')

        print("\nIniciando subida masiva a Supabase...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).upsert(lote, on_conflict='id_paradero').execute()
            print(f"   -> Procesadas filas hasta la {min(i + tamano_lote, len(datos_en_json))}")

        print(f"\n¡AL FIN! Tus datos de paradas quedaron cargados al 100% sin conflictos.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE PARADAS ORIGINAL!
# ...
#      <input type="file" id="files-bff40bfc-ff48-403b-972f-39961e6ccaba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bff40bfc-ff48-403b-972f-39961e6ccaba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'paradas'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE PARADAS ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        try:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8')
        except:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='latin-1')

        print(f"✔ Archivo cargado. Filas totales detectadas en CSV: {len(df):,}")

        # Mapeamos las 14 columnas finales usando exactamente tus nombres
        df_mapeado = pd.DataFrame()
        df_mapeado['objectid'] = pd.to_numeric(df['objectid'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['id_paradero'] = pd.to_numeric(df['id_paradero'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['id_parada'] = pd.to_numeric(df['id_parada'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['id_ruta'] = pd.to_numeric(df['id_ruta'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['nro_parada'] = pd.to_numeric(df['nro_parada'], errors='coerce').fillna(0).astype(np.int64)

        df_mapeado['nombre_ruta'] = df['nombre_ruta']
        df_mapeado['codigo_ruta'] = df['codigo_ruta']
        df_mapeado['tipo_ruta'] = df['tipo_ruta']
        df_mapeado['empresa'] = df['empresa']

        df_mapeado['longitud'] = pd.to_numeric(df['longitud'], errors='coerce')
        df_mapeado['latitud'] = pd.to_numeric(df['latitud'], errors='coerce')

        df_mapeado['recorrido'] = df['recorrido']
        df_mapeado['sistema_ruta'] = df['sistema_ruta']
        df_mapeado['tipo_parada'] = df['tipo_parada']

        # Reemplazar nulos para evitar choques con PostgreSQL
        df_mapeado = df_mapeado.replace({np.nan: None})

        print(f"✔ Listas las {len(df_mapeado.columns)} columnas con objectid para subir.")

        # Subida masiva por inserción pura (sin eliminar duplicados)
        tamano_lote = 1000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print("\nIniciando subida masiva a Supabase...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json))}")

        print(f"\n¡LISTO! Se subió la tabla con las {len(df_mapeado):,} filas completas.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE PARADAS ORIGINAL!
# ...
#      <input type="file" id="files-2abcd47c-ba1e-4a8d-865c-5a80be2c3fce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2abcd47c-ba1e-4a8d-865c-5a80be2c3fce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        try:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8')
        except:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='latin-1')

        print(f"✔ Archivo cargado. Filas totales detectadas en CSV: {len(df):,}")

        df_mapeado = pd.DataFrame()

        # 1. Enteros
        df_mapeado['id'] = pd.to_numeric(df['id'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['año'] = pd.to_numeric(df['año'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['mes'] = pd.to_numeric(df['mes'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['numcomuna'] = pd.to_numeric(df['numcomuna'], errors='coerce').fillna(0).astype(np.int64)

        # 2. Decimales
        df_mapeado['longitud'] = pd.to_numeric(df['longitud'], errors='coerce').fillna(0.0)
        df_mapeado['latitud'] = pd.to_numeric(df['latitud'], errors='coerce').fillna(0.0)

        # 3. Textos estándar
        columnas_texto = ['fecha_accidentes', 'clase_accidente', 'gravedad_accidente', 'diseño', 'barrio', 'comuna']
        for col in columnas_texto:
            if col in df.columns:
                df_mapeado[col] = df[col].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO', 'None': 'NO REPORTADO'})
            else:
                df_mapeado[col] = 'NO REPORTADO'

        # 4. Tratamiento especial para la columna JSONB (location)
        if 'location' in df.columns:
            # Si está vacío o es nulo, le ponemos un objeto JSON vacío '{}' válido para PostgreSQL
            df_mapeado['location'] = df['location'].astype(str).replace({'nan': '{}', '': '{}', 'None': '{}'})
        else:
            df_mapeado['location'] = '{}'

        # Limpieza final para Supabase
        df_mapeado = df_mapeado.replace({np.nan: None})

        print(f"✔ Estructura validada con las 13 columnas (location como JSON listo).")
        print(f"✔ Total filas listas para procesar: {len(df_mapeado):,}")

        # Subida masiva por lotes
        tamano_lote = 2000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print("\nIniciando subida masiva a Supabase...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            if i % 20000 == 0 or (i + tamano_lote) >= len(datos_en_json):
                print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json)):,}")

        print(f"\n¡LISTO! Se subió la tabla con las {len(df_mapeado):,} filas completas.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!
# ...
#      <input type="file" id="files-43d0888f-fe03-4b21-befa-6d1777b7704d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43d0888f-fe03-4b21-befa-6d1777b7704d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        # Cargamos el archivo ignorando alertas de tipos mixtos (low_memory=False)
        try:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8', low_memory=False)
        except:
            df = pd.read_csv(io.BytesIO(contenido_binario), encoding='latin-1', low_memory=False)

        print(f"✔ Archivo cargado. Filas totales detectadas en CSV: {len(df):,}")

        # --- TRUCO DE LIMPIEZA DE COLUMNAS ---
        # Pasamos todos los nombres de columnas a minúsculas y les quitamos espacios raros
        df.columns = df.columns.str.lower().str.strip()

        df_mapeado = pd.DataFrame()

        # 1. Enteros (Buscamos la columna quitando tildes por si acaso)
        col_anio = 'año' if 'año' in df.columns else ('ano' if 'ano' in df.columns else 'periodo')
        col_fecha = 'fecha_accidentes' if 'fecha_accidentes' in df.columns else 'fecha'

        df_mapeado['id'] = pd.to_numeric(df['id'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['año'] = pd.to_numeric(df[col_anio], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['mes'] = pd.to_numeric(df['mes'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['numcomuna'] = pd.to_numeric(df['numcomuna'], errors='coerce').fillna(0).astype(np.int64)

        # 2. Decimales
        df_mapeado['longitud'] = pd.to_numeric(df['longitud'], errors='coerce').fillna(0.0)
        df_mapeado['latitud'] = pd.to_numeric(df['latitud'], errors='coerce').fillna(0.0)

        # 3. Textos estándar
        df_mapeado['fecha_accidentes'] = df[col_fecha].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})

        columnas_texto = ['clase_accidente', 'gravedad_accidente', 'diseño', 'barrio', 'comuna']
        for col in columnas_texto:
            # Busgamos variaciones por si viene sin tilde en el CSV (ej: diseno)
            col_csv = col if col in df.columns else col.replace('ñ', 'n').replace('ñ', 'n')
            if col_csv in df.columns:
                df_mapeado[col] = df[col_csv].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO', 'None': 'NO REPORTADO'})
            else:
                df_mapeado[col] = 'NO REPORTADO'

        # 4. JSONB de ubicación
        if 'location' in df.columns:
            df_mapeado['location'] = df['location'].astype(str).replace({'nan': '{}', '': '{}', 'None': '{}'})
        else:
            df_mapeado['location'] = '{}'

        # Compatibilidad con PostgreSQL
        df_mapeado = df_mapeado.replace({np.nan: None})

        print(f"✔ Estructura homologada con las 13 columnas oficiales.")
        print(f"✔ Total filas listas para procesar: {len(df_mapeado):,}")

        # Subida masiva por lotes
        tamano_lote = 2000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print("\nIniciando subida masiva a Supabase (Procesando 270k filas)...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            if i % 20000 == 0 or (i + tamano_lote) >= len(datos_en_json):
                print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json)):,}")

        print(f"\n¡LISTO! Se subió la tabla con las {len(df_mapeado):,} filas completas.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!
# ...
#      <input type="file" id="files-b0696236-7bbe-4272-94a4-589981f9d6a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0696236-7bbe-4272-94a4-589981f9d6a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        # Carga limpia ignorando avisos de tipos mixtos
        df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8', low_memory=False)
        print(f"✔ Archivo cargado con éxito. Total filas detectadas: {len(df):,}")

        # Creamos el DataFrame mapeando tus 13 columnas usando los nombres EXACTOS del CSV
        df_mapeado = pd.DataFrame()

        # 1. Identificadores y Enteros (nro_radicado va para la columna id)
        df_mapeado['id'] = pd.to_numeric(df['nro_radicado'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['año'] = pd.to_numeric(df['año'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['mes'] = pd.to_numeric(df['mes'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['numcomuna'] = pd.to_numeric(df['numcomuna'], errors='coerce').fillna(0).astype(np.int64)

        # 2. Coordenadas Geográficas (Buscamos x e y que vienen en el archivo para longitud/latitud)
        df_mapeado['longitud'] = pd.to_numeric(df['x'], errors='coerce').fillna(0.0)
        df_mapeado['latitud'] = pd.to_numeric(df['y'], errors='coerce').fillna(0.0)

        # 3. Textos obligatorios (Rellenamos vacíos con "NO REPORTADO" para no perder las 20k filas)
        df_mapeado['fecha_accidentes'] = df['fecha_accidentes'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['clase_accidente'] = df['clase_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['gravedad_accidente'] = df['gravedad_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['diseño'] = df['diseno'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['barrio'] = df['barrio'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['comuna'] = df['comuna'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})

        # 4. Columna JSONB para la ubicación geográfica
        df_mapeado['location'] = df['location'].astype(str).replace({'nan': '{}', '': '{}', 'None': '{}'})

        # Limpieza final de valores nulos nulos de Pandas
        df_mapeado = df_mapeado.replace({np.nan: None})

        print(f"✔ Columnas emparejadas con éxito según las 13 oficiales del diccionario.")
        print(f"✔ Total registros listos para subir: {len(df_mapeado):,}")

        # Subida masiva por lotes
        tamano_lote = 2000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print("\nIniciando subida masiva a Supabase (Procesando las 270,765 filas)...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            if i % 20000 == 0 or (i + tamano_lote) >= len(datos_en_json):
                print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json)):,}")

        print(f"\n¡ÉXITO TOTAL! Se subió la tabla de incidentes completa con sus {len(df_mapeado):,} filas.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!
# ...
#      <input type="file" id="files-6b831b6a-0f2a-485d-8124-f521422ec12e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b831b6a-0f2a-485d-8124-f521422ec12e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8', low_memory=False)
        print(f"✔ Archivo cargado con éxito. Total filas detectadas: {len(df):,}")

        df_mapeado = pd.DataFrame()

        # 1. Identificadores y Enteros
        df_mapeado['id'] = pd.to_numeric(df['nro_radicado'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['año'] = pd.to_numeric(df['año'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['mes'] = pd.to_numeric(df['mes'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['numcomuna'] = pd.to_numeric(df['numcomuna'], errors='coerce').fillna(0).astype(np.int64)

        # 2. Coordenadas Geográficas
        df_mapeado['longitud'] = pd.to_numeric(df['x'], errors='coerce').fillna(0.0)
        df_mapeado['latitud'] = pd.to_numeric(df['y'], errors='coerce').fillna(0.0)

        # 3. Textos obligatorios
        df_mapeado['fecha_accidentes'] = df['fecha_accidentes'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['clase_accidente'] = df['clase_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['gravedad_accidente'] = df['gravedad_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['diseño'] = df['diseno'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['barrio'] = df['barrio'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['comuna'] = df['comuna'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})

        # 4. Columna JSONB
        df_mapeado['location'] = df['location'].astype(str).replace({'nan': '{}', '': '{}', 'None': '{}'})

        df_mapeado = df_mapeado.replace({np.nan: None})

        print(f"✔ Columnas emparejadas con éxito según las 13 oficiales.")

        # --- PASO DE VACIADO SEGURO ---
        print("\nVaciando registros antiguos de la tabla en Supabase para evitar duplicados...")
        # Eliminamos todo usando un filtro que siempre se cumple (id > 0)
        supabase.table(nombre_tabla).delete().gt('id', 0).execute()
        print("✔ Tabla limpia y lista para recibir la nueva data.")

        # Subida masiva por lotes
        tamano_lote = 2000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print(f"\nIniciando subida masiva de los {len(df_mapeado):,} registros...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            if i % 20000 == 0 or (i + tamano_lote) >= len(datos_en_json):
                print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json)):,}")

        print(f"\n¡ÉXITO TOTAL! Se subió la tabla completa con sus {len(df_mapeado):,} filas.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!
# ...
#      <input type="file" id="files-9f3d8737-2b18-4078-b770-e717d5639b62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f3d8737-2b18-4078-b770-e717d5639b62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client
import time

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8', low_memory=False)
        print(f"✔ Archivo cargado con éxito. Total filas detectadas: {len(df):,}")

        df_mapeado = pd.DataFrame()

        # 1. Identificadores y Enteros
        df_mapeado['id'] = pd.to_numeric(df['nro_radicado'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['año'] = pd.to_numeric(df['año'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['mes'] = pd.to_numeric(df['mes'], errors='coerce').fillna(0).astype(np.int64)
        df_mapeado['numcomuna'] = pd.to_numeric(df['numcomuna'], errors='coerce').fillna(0).astype(np.int64)

        # 2. Coordenadas Geográficas
        df_mapeado['longitud'] = pd.to_numeric(df['x'], errors='coerce').fillna(0.0)
        df_mapeado['latitud'] = pd.to_numeric(df['y'], errors='coerce').fillna(0.0)

        # 3. Textos obligatorios
        df_mapeado['fecha_accidentes'] = df['fecha_accidentes'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['clase_accidente'] = df['clase_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['gravedad_accidente'] = df['gravedad_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['diseño'] = df['diseno'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['barrio'] = df['barrio'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['comuna'] = df['comuna'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})

        # 4. Columna JSONB
        df_mapeado['location'] = df['location'].astype(str).replace({'nan': '{}', '': '{}', 'None': '{}'})

        df_mapeado = df_mapeado.replace({np.nan: None})
        print(f"✔ Columnas emparejadas con éxito según las 13 oficiales.")

        # --- SOLUCIÓN AL TIMEOUT: VACIADO SEGURO POR BLOQUES ---
        print("\nVaciando registros antiguos por bloques para evitar el timeout del servidor...")
        filas_borradas = 1
        while filas_borradas > 0:
            # Traemos un lote pequeño de IDs existentes
            res_ids = supabase.table(nombre_tabla).select('id').limit(5000).execute()
            lista_ids = [r['id'] for r in res_ids.data]
            filas_borradas = len(lista_ids)

            if filas_borradas > 0:
                # Borramos solo esos IDs
                supabase.table(nombre_tabla).delete().in_('id', lista_ids).execute()
                print(f"   -> Removidos 5,000 registros viejos...")
                time.sleep(0.3)  # Pequeño respiro para el servidor

        print("✔ Tabla completamente vacía y lista para la nueva carga.")

        # Subida masiva por lotes de inserción
        tamano_lote = 2000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print(f"\nIniciando subida masiva de los {len(df_mapeado):,} nuevos registros...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            if i % 20000 == 0 or (i + tamano_lote) >= len(datos_en_json):
                print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json)):,}")

        print(f"\n¡ÉXITO TOTAL! Se subieron las {len(df_mapeado):,} filas completas sin errores.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!
# ...
#      <input type="file" id="files-f40ae3b1-ea1b-40e1-aa06-16c5aa0ddbd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f40ae3b1-ea1b-40e1-aa06-16c5aa0ddbd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import io
import pandas as pd
import numpy as np
from google.colab import files
from supabase import create_client, Client
import time

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla = 'incidentes_viales'

print("Conectando con Supabase...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("\n========================================================")
print("¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!")
print("========================================================\n")

archivo_subido = files.upload()

if not archivo_subido:
    print("\n[ALERTA] No seleccionaste ningún archivo.")
else:
    nombre_real_archivo = list(archivo_subido.keys())[0]
    contenido_binario = archivo_subido[nombre_real_archivo]

    try:
        df = pd.read_csv(io.BytesIO(contenido_binario), encoding='utf-8', low_memory=False)
        filas_iniciales = len(df)
        print(f"✔ Archivo cargado con éxito. Filas iniciales en CSV: {filas_iniciales:,}")

        # --- FILTRO DE CALIDAD ESTRICTO (PROCESO DE LIMPIEZA MÁNAGER) ---
        print("\nAplicando filtros estrictos de calidad de datos...")

        # 1. Convertimos a numérico y eliminamos filas donde 'nro_radicado' sea nulo, vacío o 0
        df['nro_radicado_num'] = pd.to_numeric(df['nro_radicado'], errors='coerce')
        df = df.dropna(subset=['nro_radicado_num'])
        df = df[df['nro_radicado_num'] != 0]
        filas_con_id = len(df)
        print(f"   -> Filas descartadas por ID vacío o inválido: {filas_iniciales - filas_con_id:,}")

        # 2. Eliminamos duplicados basados en el ID para quedarnos solo con el primer registro único
        df = df.drop_duplicates(subset=['nro_radicado_num'], keep='first')
        filas_limpias = len(df)
        print(f"   -> Filas descartadas por IDs duplicados repetidos: {filas_con_id - filas_limpias:,}")
        print(f"✔ TOTAL FILAS PURAS Y VÁLIDAS PARA SUBIR: {filas_limpias:,}")

        # Mapeamos los datos limpios a tu estructura oficial de 13 campos
        df_mapeado = pd.DataFrame()
        df_mapeado['id'] = df['nro_radicado_num'].astype(np.int64)
        df_mapeado['año'] = pd.to_numeric(df['año'], errors='coerce').fillna(2026).astype(np.int64)
        df_mapeado['mes'] = pd.to_numeric(df['mes'], errors='coerce').fillna(1).astype(np.int64)
        df_mapeado['numcomuna'] = pd.to_numeric(df['numcomuna'], errors='coerce').fillna(0).astype(np.int64)

        # Coordenadas
        df_mapeado['longitud'] = pd.to_numeric(df['x'], errors='coerce').fillna(0.0)
        df_mapeado['latitud'] = pd.to_numeric(df['y'], errors='coerce').fillna(0.0)

        # Textos oficiales
        df_mapeado['fecha_accidentes'] = df['fecha_accidentes'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['clase_accidente'] = df['clase_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['gravedad_accidente'] = df['gravedad_accidente'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['diseño'] = df['diseno'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['barrio'] = df['barrio'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})
        df_mapeado['comuna'] = df['comuna'].astype(str).replace({'nan': 'NO REPORTADO', '': 'NO REPORTADO'})

        # JSONB
        df_mapeado['location'] = df['location'].astype(str).replace({'nan': '{}', '': '{}', 'None': '{}'})

        df_mapeado = df_mapeado.replace({np.nan: None})

        # --- VACIADO SEGURO DE REGISTROS VIEJOS ---
        print("\nLimpiando rastro del intento anterior en Supabase por bloques...")
        filas_borradas = 1
        while filas_borradas > 0:
            res_ids = supabase.table(nombre_tabla).select('id').limit(5000).execute()
            lista_ids = [r['id'] for r in res_ids.data]
            filas_borradas = len(lista_ids)
            if filas_borradas > 0:
                supabase.table(nombre_tabla).delete().in_('id', lista_ids).execute()
                time.sleep(0.2)

        print("✔ Tabla en Supabase completamente limpia de pruebas anteriores.")

        # Subida masiva por lotes
        tamano_lote = 2000
        datos_en_json = df_mapeado.to_dict(orient='records')

        print(f"\nIniciando subida masiva de los {len(df_mapeado):,} registros limpios y validados...")
        for i in range(0, len(datos_en_json), tamano_lote):
            lote = datos_en_json[i:i + tamano_lote]
            supabase.table(nombre_tabla).insert(lote).execute()
            if i % 20000 == 0 or (i + tamano_lote) >= len(datos_en_json):
                print(f"   -> Cargadas filas hasta la {min(i + tamano_lote, len(datos_en_json)):,}")

        print(f"\n¡AHORA SÍ! CONTROL DE CALIDAD COMPLETO. Se subieron {len(df_mapeado):,} registros perfectos a Supabase.")

    except Exception as e:
        print(f"Error en el proceso: {e}")
# Out:
# Conectando con Supabase...
#
# ...
# ¡SELECCIONA EL ARCHIVO DE INCIDENTES ORIGINAL!
# ...
#      <input type="file" id="files-40c740d0-fa2b-46cb-9f73-9dac344d7f32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40c740d0-fa2b-46cb-9f73-9dac344d7f32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Pegar esto en una nueva celda en Colab para descargar el archivo limpio de la memoria de Python
print(f"Generando el archivo CSV con las {len(df_mapeado):,} filas limpias...")

# Guardamos el archivo mapeado y limpio en el entorno de Colab
nombre_archivo_github = 'incidentes_viales_limpio.csv'
df_mapeado.to_csv(nombre_archivo_github, index=False, encoding='utf-8')

# Iniciamos la descarga automática en tu navegador
from google.colab import files
files.download(nombre_archivo_github)
print("✔ ¡Descarga iniciada! Este es el archivo pulido listo para tu GitHub.")
# Out:
# Generando el archivo CSV con las 270,693 filas limpias...
# ✔ ¡Descarga iniciada! Este es el archivo pulido listo para tu GitHub.

# %%
import pandas as pd
from supabase import create_client, Client
from google.colab import files

# Credenciales de tu proyecto
SUPABASE_URL = "https://dutltpmxhiqltrfidvkq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImR1dGx0cG14aGlxbHRyZmlkdmtxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzY4OTM1MTQsImV4cCI6MjA5MjQ2OTUxNH0.MyRh7y5NegTHxk-bfUSffgVb9zx4AJ30Q8xiRu18zMw"
nombre_tabla_paradas = 'paradas'  # Si en Supabase se llama diferente, cámbialo acá

print("Conectando con Supabase para traer el archivo de paradas...")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

try:
    # Traemos los datos de las paradas
    # Nota: Si la tabla es muy grande, Supabase la paginará de forma automática
    res = supabase.table(nombre_tabla_paradas).select("*").limit(5000).execute()

    if res.data:
        df_paradas = pd.DataFrame(res.data)
        nombre_archivo_paradas = 'paradas_limpio.csv'

        # Lo convertimos a CSV en la memoria de Python
        df_paradas.to_csv(nombre_archivo_paradas, index=False, encoding='utf-8')
        print(f"✔ Archivo de paradas generado con {len(df_paradas):,} registros.")

        # Descarga automática al computador
        files.download(nombre_archivo_paradas)
        print("✔ ¡Descarga iniciada! Ya tienes el de paradas listo para GitHub.")
    else:
        print("[ALERTA] No se encontraron datos en la tabla de paradas. Verifica el nombre.")

except Exception as e:
    print(f"Error al procesar el archivo de paradas: {e}")
# Out:
# Conectando con Supabase para traer el archivo de paradas...
# [ALERTA] No se encontraron datos en la tabla de paradas. Verifica el nombre.
