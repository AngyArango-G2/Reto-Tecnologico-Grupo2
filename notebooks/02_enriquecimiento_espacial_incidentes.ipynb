# %%
from google.colab import files
import pandas as pd

# SUBIR PRIMER ARCHIVO
print("SUBE incidentes_viales_validado.csv")
files.upload()

# SUBIR SEGUNDO ARCHIVO
print("SUBE incidentes_limpia_final (1).csv")
files.upload()

# LEER ARCHIVOS
df1 = pd.read_csv('/content/incidentes_viales_validado.csv')
df2 = pd.read_csv('/content/incidentes_limpia_final (1).csv')

# AGREGAR LOCATION
df1['Location'] = df2['location']

# GUARDAR
df1.to_csv('/content/incidentes_final.csv', index=False)

# DESCARGAR
files.download('/content/incidentes_final.csv')
